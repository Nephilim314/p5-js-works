# %%
import pandas as pd
import numpy
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/Users/DarkWizard/Downloads/developer_survey_2017/survey_results_public.csv")

# %%
df = df.rename(lambda x: x.lower(), axis='columns')
df
# Out:
#        respondent                                       professional  \
# 0               1                                            Student
# 1               2                                            Student
# 2               3                             Professional developer
# 3               4  Professional non-developer who sometimes write...
# 4               5                             Professional developer
# 5               6                                            Student
# 6               7  Professional non-developer who sometimes write...
# 7               8                             Professional developer
# 8               9                             Professional developer
# 9              10                             Professional developer
# 10             11  Professional non-developer who sometimes write...
# 11             12                             Professional developer
# 12             13                Used to be a professional developer
# 13             14                             Professional developer
# 14             15                             Professional developer
# 15             16                             Professional developer
# 16             17                             Professional developer
# 17             18                             Professional developer
# 18             19                             Professional developer
# 19             20                             Professional developer
# 20             21                             Professional developer
# 21             22                             Professional developer
# 22             23                             Professional developer
# 23             24                             Professional developer
# 24             25                             Professional developer
# 25             26                             Professional developer
# 26             27                             Professional developer
# 27             28                             Professional developer
# 28             29  Professional non-developer who sometimes write...
# 29             30  Professional non-developer who sometimes write...
# ...           ...                                                ...
# 51362       51363                             Professional developer
# 51363       51364                             Professional developer
# 51364       51365                             Professional developer
# 51365       51366                             Professional developer
# 51366       51367                             Professional developer
# 51367       51368                                            Student
# 51368       51369                             Professional developer
# 51369       51370                                            Student
# 51370       51371                             Professional developer
# 51371       51372                             Professional developer
# 51372       51373                             Professional developer
# 51373       51374                             Professional developer
# 51374       51375                             Professional developer
# 51375       51376                             Professional developer
# 51376       51377                                            Student
# 51377       51378                             Professional developer
# 51378       51379                             Professional developer
# 51379       51380                                            Student
# 51380       51381                             Professional developer
# 51381       51382  Professional non-developer who sometimes write...
# 51382       51383                             Professional developer
# 51383       51384                             Professional developer
# 51384       51385                             Professional developer
# 51385       51386                Used to be a professional developer
# 51386       51387                             Professional developer
# 51387       51388                             Professional developer
# 51388       51389                                            Student
# 51389       51390                             Professional developer
# 51390       51391                             Professional developer
# 51391       51392  Professional non-developer who sometimes write...
#
#                                     programhobby         country  \
# 0                                      Yes, both   United States
# 1                                      Yes, both  United Kingdom
# 2                                      Yes, both  United Kingdom
# 3                                      Yes, both   United States
# 4                      Yes, I program as a hobby     Switzerland
# 5                                      Yes, both     New Zealand
# 6                                      Yes, both   United States
# 7                                      Yes, both          Poland
# 8                      Yes, I program as a hobby        Colombia
# 9                      Yes, I program as a hobby          France
# 10                     Yes, I program as a hobby   United States
# 11                                            No          Canada
# 12                     Yes, I program as a hobby  United Kingdom
# 13                                     Yes, both         Germany
# 14                     Yes, I program as a hobby  United Kingdom
# 15                     Yes, I program as a hobby   United States
# 16                                     Yes, both  United Kingdom
# 17                                     Yes, both   United States
# 18                     Yes, I program as a hobby   United States
# 19                     Yes, I program as a hobby          Greece
# 20                     Yes, I program as a hobby          Brazil
# 21                     Yes, I program as a hobby  United Kingdom
# 22                                            No          Israel
# 23                                     Yes, both           Italy
# 24                     Yes, I program as a hobby         Belgium
# 25                     Yes, I program as a hobby   United States
# 26                                            No           India
# 27                     Yes, I program as a hobby   United States
# 28                                     Yes, both          Israel
# 29                     Yes, I program as a hobby   United States
# ...                                          ...             ...
# 51362                                         No   United States
# 51363                  Yes, I program as a hobby         Estonia
# 51364  Yes, I contribute to open source projects         Germany
# 51365                  Yes, I program as a hobby  Czech Republic
# 51366                  Yes, I program as a hobby          Sweden
# 51367                                  Yes, both           Spain
# 51368                  Yes, I program as a hobby          Taiwan
# 51369                  Yes, I program as a hobby          Poland
# 51370                  Yes, I program as a hobby  United Kingdom
# 51371                                         No     Netherlands
# 51372                  Yes, I program as a hobby  United Kingdom
# 51373                                  Yes, both   United States
# 51374                  Yes, I program as a hobby          Sweden
# 51375                                         No  United Kingdom
# 51376                  Yes, I program as a hobby         Germany
# 51377                                         No  United Kingdom
# 51378  Yes, I contribute to open source projects          Cyprus
# 51379                  Yes, I program as a hobby         Belgium
# 51380                  Yes, I program as a hobby   United States
# 51381                                  Yes, both   United States
# 51382                  Yes, I program as a hobby          France
# 51383                  Yes, I program as a hobby          Sweden
# 51384                                         No   United States
# 51385                                  Yes, both  United Kingdom
# 51386                                  Yes, both         Romania
# 51387                  Yes, I program as a hobby   United States
# 51388                                         No       Venezuela
# 51389                  Yes, I program as a hobby          Canada
# 51390                  Yes, I program as a hobby   United States
# 51391                                         No         Ireland
#
#                 university                                   employmentstatus  \
# 0                       No             Not employed, and not looking for work
# 1           Yes, full-time                                 Employed part-time
# 2                       No                                 Employed full-time
# 3                       No                                 Employed full-time
# 4                       No                                 Employed full-time
# 5           Yes, full-time             Not employed, and not looking for work
# 6                       No                                 Employed full-time
# 7                       No                                 Employed full-time
# 8           Yes, part-time                                 Employed full-time
# 9           Yes, full-time  Independent contractor, freelancer, or self-em...
# 10                      No                                 Employed full-time
# 11                      No                                 Employed full-time
# 12                      No                 Not employed, but looking for work
# 13                      No                                 Employed full-time
# 14                      No                                 Employed full-time
# 15          Yes, part-time  Independent contractor, freelancer, or self-em...
# 16                      No             Not employed, and not looking for work
# 17          Yes, part-time                                 Employed full-time
# 18                      No                                 Employed full-time
# 19                      No                                 Employed full-time
# 20                      No                                 Employed full-time
# 21                      No                                 Employed full-time
# 22                      No                                 Employed full-time
# 23                      No  Independent contractor, freelancer, or self-em...
# 24                      No                                 Employed full-time
# 25                      No                                 Employed full-time
# 26                      No                                 Employed full-time
# 27                      No                                 Employed full-time
# 28                      No                                 Employed full-time
# 29                      No                                 Employed full-time
# ...                    ...                                                ...
# 51362                   No  Independent contractor, freelancer, or self-em...
# 51363  I prefer not to say  Independent contractor, freelancer, or self-em...
# 51364                   No  Independent contractor, freelancer, or self-em...
# 51365                   No                                 Employed full-time
# 51366                   No                                 Employed full-time
# 51367       Yes, full-time                                 Employed part-time
# 51368                   No                                 Employed full-time
# 51369       Yes, full-time                                 Employed part-time
# 51370                   No  Independent contractor, freelancer, or self-em...
# 51371                   No                                 Employed full-time
# 51372       Yes, full-time                                 Employed full-time
# 51373                   No  Independent contractor, freelancer, or self-em...
# 51374                   No                                 Employed full-time
# 51375                   No                                 Employed full-time
# 51376       Yes, full-time  Independent contractor, freelancer, or self-em...
# 51377                   No                                 Employed full-time
# 51378                   No                                 Employed part-time
# 51379                   No                                 Employed full-time
# 51380                   No                                 Employed full-time
# 51381                   No                                 Employed full-time
# 51382                   No                                 Employed full-time
# 51383                   No  Independent contractor, freelancer, or self-em...
# 51384                   No                                 Employed full-time
# 51385                   No                                 Employed full-time
# 51386                   No                                 Employed full-time
# 51387                   No                                 Employed full-time
# 51388       Yes, full-time                                 Employed full-time
# 51389                   No                                 Employed full-time
# 51390                   No                                 Employed full-time
# 51391                   No                                 Employed full-time
#
#                                          formaleducation  \
# 0                                       Secondary school
# 1      Some college/university study without earning ...
# 2                                      Bachelor's degree
# 3                                        Doctoral degree
# 4                                        Master's degree
# 5                                       Secondary school
# 6                                        Master's degree
# 7                                        Master's degree
# 8                                      Bachelor's degree
# 9                                        Master's degree
# 10                                     Bachelor's degree
# 11                                     Bachelor's degree
# 12                                     Bachelor's degree
# 13     Some college/university study without earning ...
# 14                                   Professional degree
# 15                             Primary/elementary school
# 16                                      Secondary school
# 17                                     Bachelor's degree
# 18                                     Bachelor's degree
# 19                                       Doctoral degree
# 20                                     Bachelor's degree
# 21                                     Bachelor's degree
# 22                                     Bachelor's degree
# 23                                      Secondary school
# 24                                       Master's degree
# 25                                       Master's degree
# 26                                     Bachelor's degree
# 27                                     Bachelor's degree
# 28     Some college/university study without earning ...
# 29                                     Bachelor's degree
# ...                                                  ...
# 51362                                    Master's degree
# 51363                                  Bachelor's degree
# 51364                                   Secondary school
# 51365  Some college/university study without earning ...
# 51366                                    Master's degree
# 51367                                  Bachelor's degree
# 51368                                    Master's degree
# 51369  Some college/university study without earning ...
# 51370  Some college/university study without earning ...
# 51371                                  Bachelor's degree
# 51372                                   Secondary school
# 51373  Some college/university study without earning ...
# 51374                                  Bachelor's degree
# 51375                                  Bachelor's degree
# 51376                                   Secondary school
# 51377                                  Bachelor's degree
# 51378                                   Secondary school
# 51379                                    Master's degree
# 51380  Some college/university study without earning ...
# 51381                                    Doctoral degree
# 51382                                    Master's degree
# 51383             I never completed any formal education
# 51384                                  Bachelor's degree
# 51385                                    Master's degree
# 51386  Some college/university study without earning ...
# 51387                                  Bachelor's degree
# 51388                                    Master's degree
# 51389  Some college/university study without earning ...
# 51390                                  Bachelor's degree
# 51391                                  Bachelor's degree
#
#                                           majorundergrad  \
# 0                                                    NaN
# 1               Computer science or software engineering
# 2               Computer science or software engineering
# 3          A non-computer-focused engineering discipline
# 4               Computer science or software engineering
# 5                                                    NaN
# 6          A non-computer-focused engineering discipline
# 7               Computer science or software engineering
# 8               Computer science or software engineering
# 9               Computer science or software engineering
# 10                                      A social science
# 11              Computer science or software engineering
# 12                             Mathematics or statistics
# 13              Computer science or software engineering
# 14     Computer engineering or electrical/electronics...
# 15                                                   NaN
# 16                                                   NaN
# 17              Computer science or software engineering
# 18              Computer science or software engineering
# 19                                     A natural science
# 20              Computer science or software engineering
# 21                                     A natural science
# 22     Computer engineering or electrical/electronics...
# 23                                                   NaN
# 24              Computer science or software engineering
# 25              Computer science or software engineering
# 26              Computer science or software engineering
# 27                                 A business discipline
# 28     Computer engineering or electrical/electronics...
# 29                                 A business discipline
# ...                                                  ...
# 51362                     Management information systems
# 51363  Information technology, networking, or system ...
# 51364                                                NaN
# 51365                                  A natural science
# 51366           Computer science or software engineering
# 51367  Computer engineering or electrical/electronics...
# 51368                                   A social science
# 51369           Computer science or software engineering
# 51370                           I never declared a major
# 51371           Computer science or software engineering
# 51372                                                NaN
# 51373           Computer science or software engineering
# 51374           Computer science or software engineering
# 51375            Computer programming or Web development
# 51376                                                NaN
# 51377           Computer science or software engineering
# 51378                                                NaN
# 51379      A non-computer-focused engineering discipline
# 51380            Computer programming or Web development
# 51381                                         Psychology
# 51382           Computer science or software engineering
# 51383                                                NaN
# 51384            Computer programming or Web development
# 51385                              A business discipline
# 51386                                     Something else
# 51387                                   A social science
# 51388            Computer programming or Web development
# 51389  Information technology, networking, or system ...
# 51390           Computer science or software engineering
# 51391           Computer science or software engineering
#
#                                               homeremote  \
# 0                                                    NaN
# 1                  More than half, but not all, the time
# 2      Less than half the time, but at least one day ...
# 3      Less than half the time, but at least one day ...
# 4                                                  Never
# 5                                                    NaN
# 6      Less than half the time, but at least one day ...
# 7      All or almost all the time (I'm full-time remote)
# 8      Less than half the time, but at least one day ...
# 9                                       It's complicated
# 10     All or almost all the time (I'm full-time remote)
# 11                                 A few days each month
# 12                                                   NaN
# 13     Less than half the time, but at least one day ...
# 14     All or almost all the time (I'm full-time remote)
# 15     All or almost all the time (I'm full-time remote)
# 16                                                   NaN
# 17     All or almost all the time (I'm full-time remote)
# 18                                 A few days each month
# 19     Less than half the time, but at least one day ...
# 20     Less than half the time, but at least one day ...
# 21                                 A few days each month
# 22                                 A few days each month
# 23     All or almost all the time (I'm full-time remote)
# 24                                                 Never
# 25     Less than half the time, but at least one day ...
# 26                                                 Never
# 27                                 A few days each month
# 28                                 A few days each month
# 29     Less than half the time, but at least one day ...
# ...                                                  ...
# 51362  All or almost all the time (I'm full-time remote)
# 51363  Less than half the time, but at least one day ...
# 51364  Less than half the time, but at least one day ...
# 51365                                About half the time
# 51366                                   It's complicated
# 51367                                About half the time
# 51368                                              Never
# 51369                                About half the time
# 51370  All or almost all the time (I'm full-time remote)
# 51371  All or almost all the time (I'm full-time remote)
# 51372                                              Never
# 51373  All or almost all the time (I'm full-time remote)
# 51374                              A few days each month
# 51375                              A few days each month
# 51376                                              Never
# 51377                              A few days each month
# 51378  All or almost all the time (I'm full-time remote)
# 51379                                              Never
# 51380              More than half, but not all, the time
# 51381              More than half, but not all, the time
# 51382                                              Never
# 51383  All or almost all the time (I'm full-time remote)
# 51384                                              Never
# 51385                              A few days each month
# 51386                                   It's complicated
# 51387                              A few days each month
# 51388                                              Never
# 51389  Less than half the time, but at least one day ...
# 51390                                              Never
# 51391                                   It's complicated
#
#                     companysize       ...       stackoverflowmakemoney  \
# 0                           NaN       ...            Strongly disagree
# 1            20 to 99 employees       ...            Strongly disagree
# 2      10,000 or more employees       ...                     Disagree
# 3      10,000 or more employees       ...                     Disagree
# 4            10 to 19 employees       ...                          NaN
# 5                           NaN       ...                     Disagree
# 6            20 to 99 employees       ...                     Disagree
# 7       Fewer than 10 employees       ...               Somewhat agree
# 8      5,000 to 9,999 employees       ...            Strongly disagree
# 9                           NaN       ...                     Disagree
# 10         100 to 499 employees       ...            Strongly disagree
# 11         100 to 499 employees       ...                          NaN
# 12                          NaN       ...            Strongly disagree
# 13      Fewer than 10 employees       ...                     Disagree
# 14     5,000 to 9,999 employees       ...                     Disagree
# 15                          NaN       ...                     Disagree
# 16                          NaN       ...            Strongly disagree
# 17     1,000 to 4,999 employees       ...                     Disagree
# 18     10,000 or more employees       ...                          NaN
# 19      Fewer than 10 employees       ...            Strongly disagree
# 20     10,000 or more employees       ...                          NaN
# 21           20 to 99 employees       ...                     Disagree
# 22         500 to 999 employees       ...               Somewhat agree
# 23                          NaN       ...                     Disagree
# 24           20 to 99 employees       ...                          NaN
# 25     10,000 or more employees       ...                     Disagree
# 26     5,000 to 9,999 employees       ...                          NaN
# 27         100 to 499 employees       ...                          NaN
# 28           10 to 19 employees       ...                     Disagree
# 29     10,000 or more employees       ...                          NaN
# ...                         ...       ...                          ...
# 51362                       NaN       ...            Strongly disagree
# 51363                       NaN       ...                          NaN
# 51364                       NaN       ...                     Disagree
# 51365  10,000 or more employees       ...                          NaN
# 51366  1,000 to 4,999 employees       ...                          NaN
# 51367              I don't know       ...                     Disagree
# 51368  5,000 to 9,999 employees       ...                     Disagree
# 51369   Fewer than 10 employees       ...                     Disagree
# 51370                       NaN       ...                     Disagree
# 51371   Fewer than 10 employees       ...                     Disagree
# 51372   Fewer than 10 employees       ...                          NaN
# 51373                       NaN       ...            Strongly disagree
# 51374      100 to 499 employees       ...                          NaN
# 51375  1,000 to 4,999 employees       ...                     Disagree
# 51376                       NaN       ...                     Disagree
# 51377  1,000 to 4,999 employees       ...                     Disagree
# 51378   Fewer than 10 employees       ...            Strongly disagree
# 51379  10,000 or more employees       ...                          NaN
# 51380  10,000 or more employees       ...                          NaN
# 51381  10,000 or more employees       ...            Strongly disagree
# 51382      100 to 499 employees       ...                     Disagree
# 51383                       NaN       ...            Strongly disagree
# 51384        20 to 99 employees       ...                     Disagree
# 51385  1,000 to 4,999 employees       ...               Somewhat agree
# 51386      100 to 499 employees       ...               Somewhat agree
# 51387      100 to 499 employees       ...                     Disagree
# 51388      100 to 499 employees       ...                          NaN
# 51389        10 to 19 employees       ...                          NaN
# 51390   Fewer than 10 employees       ...                     Disagree
# 51391  10,000 or more employees       ...               Somewhat agree
#
#        gender                            highesteducationparents  \
# 0        Male                                        High school
# 1        Male                                  A master's degree
# 2        Male                              A professional degree
# 3        Male                                  A doctoral degree
# 4         NaN                                                NaN
# 5         NaN                                A bachelor's degree
# 6        Male                                  A doctoral degree
# 7        Male                                  A master's degree
# 8        Male                                A bachelor's degree
# 9        Male                                  A doctoral degree
# 10     Female  Some college/university study, no bachelor's d...
# 11        NaN                                                NaN
# 12       Male                                A bachelor's degree
# 13     Female                                  A master's degree
# 14       Male                                        High school
# 15       Male                                  A doctoral degree
# 16       Male                                        High school
# 17       Male                                  A master's degree
# 18        NaN                                                NaN
# 19       Male                                  A master's degree
# 20        NaN                                                NaN
# 21       Male                                A bachelor's degree
# 22       Male                                A bachelor's degree
# 23       Male                                        High school
# 24        NaN                                                NaN
# 25       Male                                  A master's degree
# 26        NaN                                                NaN
# 27        NaN                                                NaN
# 28       Male                                A bachelor's degree
# 29        NaN                                                NaN
# ...       ...                                                ...
# 51362    Male                                  A master's degree
# 51363    Male                                  A master's degree
# 51364    Male                                        High school
# 51365    Male                                  A master's degree
# 51366     NaN                                                NaN
# 51367  Female                                A bachelor's degree
# 51368    Male                                  A master's degree
# 51369    Male                                  A master's degree
# 51370    Male  Some college/university study, no bachelor's d...
# 51371    Male                                A bachelor's degree
# 51372     NaN                                                NaN
# 51373    Male  Some college/university study, no bachelor's d...
# 51374     NaN                                                NaN
# 51375    Male                                A bachelor's degree
# 51376    Male                                A bachelor's degree
# 51377    Male                          Primary/elementary school
# 51378    Male                                  A doctoral degree
# 51379     NaN                                                NaN
# 51380    Male                                        High school
# 51381    Male                                A bachelor's degree
# 51382    Male                                  A master's degree
# 51383    Male  Some college/university study, no bachelor's d...
# 51384    Male                                  A master's degree
# 51385  Female                                        High school
# 51386    Male                                        High school
# 51387    Male                                  A doctoral degree
# 51388    Male                                  A master's degree
# 51389     NaN                                                NaN
# 51390    Male                                A bachelor's degree
# 51391    Male                                A bachelor's degree
#
#                                                     race         surveylong  \
# 0                           White or of European descent  Strongly disagree
# 1                           White or of European descent     Somewhat agree
# 2                           White or of European descent     Somewhat agree
# 3                           White or of European descent              Agree
# 4                                                    NaN                NaN
# 5                           White or of European descent           Disagree
# 6                           White or of European descent           Disagree
# 7                           White or of European descent              Agree
# 8                              Hispanic or Latino/Latina     Somewhat agree
# 9                           White or of European descent     Somewhat agree
# 10                          White or of European descent  Strongly disagree
# 11                                                   NaN                NaN
# 12                          White or of European descent           Disagree
# 13                             Hispanic or Latino/Latina     Somewhat agree
# 14                          White or of European descent     Somewhat agree
# 15                          White or of European descent           Disagree
# 16                          White or of European descent           Disagree
# 17     Native American, Pacific Islander, or Indigeno...           Disagree
# 18                                                   NaN                NaN
# 19                                   I prefer not to say              Agree
# 20                                                   NaN                NaN
# 21                          White or of European descent     Somewhat agree
# 22                          White or of European descent     Strongly agree
# 23                          White or of European descent              Agree
# 24                                                   NaN                NaN
# 25                          White or of European descent           Disagree
# 26                                                   NaN                NaN
# 27                                                   NaN                NaN
# 28                          White or of European descent     Somewhat agree
# 29                                                   NaN                NaN
# ...                                                  ...                ...
# 51362                       White or of European descent           Disagree
# 51363                       White or of European descent     Strongly agree
# 51364                       White or of European descent     Somewhat agree
# 51365                       White or of European descent     Strongly agree
# 51366                                                NaN                NaN
# 51367  Hispanic or Latino/Latina; White or of Europea...     Somewhat agree
# 51368                       White or of European descent           Disagree
# 51369                       White or of European descent              Agree
# 51370                       White or of European descent           Disagree
# 51371                       White or of European descent           Disagree
# 51372                                                NaN                NaN
# 51373                                                NaN           Disagree
# 51374                                                NaN                NaN
# 51375                       White or of European descent           Disagree
# 51376                       White or of European descent     Somewhat agree
# 51377                                                NaN     Strongly agree
# 51378                                                NaN     Somewhat agree
# 51379                                                NaN                NaN
# 51380                       White or of European descent              Agree
# 51381                       White or of European descent     Somewhat agree
# 51382                       White or of European descent              Agree
# 51383                       White or of European descent              Agree
# 51384                       White or of European descent     Somewhat agree
# 51385                       White or of European descent     Somewhat agree
# 51386                       White or of European descent              Agree
# 51387           East Asian; White or of European descent           Disagree
# 51388  Black or of African descent; Hispanic or Latin...     Somewhat agree
# 51389                                                NaN                NaN
# 51390                       White or of European descent           Disagree
# 51391                       White or of European descent     Somewhat agree
#
#       questionsinteresting questionsconfusing interestedanswers  \
# 0           Strongly agree           Disagree    Strongly agree
# 1           Somewhat agree           Disagree    Strongly agree
# 2                    Agree           Disagree             Agree
# 3                    Agree     Somewhat agree    Strongly agree
# 4                      NaN                NaN               NaN
# 5                    Agree           Disagree             Agree
# 6                    Agree           Disagree             Agree
# 7           Somewhat agree           Disagree             Agree
# 8           Strongly agree           Disagree    Strongly agree
# 9                    Agree           Disagree             Agree
# 10                   Agree  Strongly disagree    Strongly agree
# 11                     NaN                NaN               NaN
# 12          Somewhat agree           Disagree             Agree
# 13                   Agree           Disagree    Strongly agree
# 14                   Agree           Disagree             Agree
# 15          Somewhat agree  Strongly disagree             Agree
# 16                   Agree  Strongly disagree    Strongly agree
# 17                   Agree           Disagree             Agree
# 18                     NaN                NaN               NaN
# 19          Somewhat agree           Disagree    Somewhat agree
# 20                     NaN                NaN               NaN
# 21          Somewhat agree           Disagree             Agree
# 22          Somewhat agree     Somewhat agree             Agree
# 23                   Agree           Disagree             Agree
# 24                     NaN                NaN               NaN
# 25          Strongly agree           Disagree    Strongly agree
# 26                     NaN                NaN               NaN
# 27                     NaN                NaN               NaN
# 28          Somewhat agree           Disagree             Agree
# 29                     NaN                NaN               NaN
# ...                    ...                ...               ...
# 51362                Agree           Disagree             Agree
# 51363       Somewhat agree           Disagree             Agree
# 51364                Agree  Strongly disagree    Strongly agree
# 51365       Somewhat agree           Disagree          Disagree
# 51366                  NaN                NaN               NaN
# 51367       Somewhat agree  Strongly disagree             Agree
# 51368       Strongly agree  Strongly disagree    Strongly agree
# 51369             Disagree           Disagree             Agree
# 51370                Agree  Strongly disagree    Strongly agree
# 51371                Agree  Strongly disagree             Agree
# 51372                  NaN                NaN               NaN
# 51373                Agree           Disagree    Somewhat agree
# 51374                  NaN                NaN               NaN
# 51375                Agree  Strongly disagree    Strongly agree
# 51376                Agree           Disagree             Agree
# 51377       Somewhat agree           Disagree    Strongly agree
# 51378       Strongly agree  Strongly disagree    Strongly agree
# 51379                  NaN                NaN               NaN
# 51380       Somewhat agree           Disagree    Somewhat agree
# 51381       Strongly agree  Strongly disagree    Strongly agree
# 51382                Agree           Disagree    Somewhat agree
# 51383       Somewhat agree  Strongly disagree          Disagree
# 51384                Agree           Disagree    Somewhat agree
# 51385       Strongly agree           Disagree    Strongly agree
# 51386                Agree           Disagree    Somewhat agree
# 51387                Agree  Strongly disagree    Strongly agree
# 51388                Agree           Disagree             Agree
# 51389                  NaN                NaN               NaN
# 51390                Agree           Disagree    Strongly agree
# 51391       Strongly agree           Disagree    Strongly agree
#
#               salary  expectedsalary
# 0                NaN             NaN
# 1                NaN    37500.000000
# 2      113750.000000             NaN
# 3                NaN             NaN
# 4                NaN             NaN
# 5                NaN             NaN
# 6                NaN             NaN
# 7                NaN             NaN
# 8                NaN             NaN
# 9                NaN             NaN
# 10               NaN             NaN
# 11               NaN             NaN
# 12               NaN             NaN
# 13               NaN             NaN
# 14     100000.000000             NaN
# 15               NaN             NaN
# 16               NaN             NaN
# 17     130000.000000             NaN
# 18      82500.000000             NaN
# 19               NaN             NaN
# 20               NaN             NaN
# 21               NaN             NaN
# 22     100764.000000             NaN
# 23               NaN             NaN
# 24               NaN             NaN
# 25     175000.000000             NaN
# 26               NaN             NaN
# 27               NaN             NaN
# 28               NaN             NaN
# 29               NaN             NaN
# ...              ...             ...
# 51362            NaN             NaN
# 51363            NaN             NaN
# 51364            NaN             NaN
# 51365            NaN             NaN
# 51366            NaN             NaN
# 51367            NaN             NaN
# 51368            NaN             NaN
# 51369            NaN    14814.814815
# 51370            NaN             NaN
# 51371   74193.548387             NaN
# 51372            NaN             NaN
# 51373            NaN             NaN
# 51374            NaN             NaN
# 51375            NaN             NaN
# 51376            NaN    43010.752688
# 51377            NaN             NaN
# 51378  107526.881720             NaN
# 51379            NaN    26881.720430
# 51380            NaN             NaN
# 51381            NaN             NaN
# 51382   32258.064516             NaN
# 51383            NaN             NaN
# 51384            NaN             NaN
# 51385            NaN             NaN
# 51386            NaN             NaN
# 51387   58000.000000             NaN
# 51388            NaN             NaN
# 51389            NaN             NaN
# 51390   40000.000000             NaN
# 51391            NaN             NaN
#
# [51392 rows x 154 columns]

# %%
df_dev_profile = df[['respondent', 'professional', 'gender', 'race', 'country', 'currency',
                     'university', 'majorundergrad', 'salary', 'expectedsalary']]

# %%
df_dev_profile
# Out:
#        respondent                                       professional  gender  \
# 0               1                                            Student    Male
# 1               2                                            Student    Male
# 2               3                             Professional developer    Male
# 3               4  Professional non-developer who sometimes write...    Male
# 4               5                             Professional developer     NaN
# 5               6                                            Student     NaN
# 6               7  Professional non-developer who sometimes write...    Male
# 7               8                             Professional developer    Male
# 8               9                             Professional developer    Male
# 9              10                             Professional developer    Male
# 10             11  Professional non-developer who sometimes write...  Female
# 11             12                             Professional developer     NaN
# 12             13                Used to be a professional developer    Male
# 13             14                             Professional developer  Female
# 14             15                             Professional developer    Male
# 15             16                             Professional developer    Male
# 16             17                             Professional developer    Male
# 17             18                             Professional developer    Male
# 18             19                             Professional developer     NaN
# 19             20                             Professional developer    Male
# 20             21                             Professional developer     NaN
# 21             22                             Professional developer    Male
# 22             23                             Professional developer    Male
# 23             24                             Professional developer    Male
# 24             25                             Professional developer     NaN
# 25             26                             Professional developer    Male
# 26             27                             Professional developer     NaN
# 27             28                             Professional developer     NaN
# 28             29  Professional non-developer who sometimes write...    Male
# 29             30  Professional non-developer who sometimes write...     NaN
# ...           ...                                                ...     ...
# 51362       51363                             Professional developer    Male
# 51363       51364                             Professional developer    Male
# 51364       51365                             Professional developer    Male
# 51365       51366                             Professional developer    Male
# 51366       51367                             Professional developer     NaN
# 51367       51368                                            Student  Female
# 51368       51369                             Professional developer    Male
# 51369       51370                                            Student    Male
# 51370       51371                             Professional developer    Male
# 51371       51372                             Professional developer    Male
# 51372       51373                             Professional developer     NaN
# 51373       51374                             Professional developer    Male
# 51374       51375                             Professional developer     NaN
# 51375       51376                             Professional developer    Male
# 51376       51377                                            Student    Male
# 51377       51378                             Professional developer    Male
# 51378       51379                             Professional developer    Male
# 51379       51380                                            Student     NaN
# 51380       51381                             Professional developer    Male
# 51381       51382  Professional non-developer who sometimes write...    Male
# 51382       51383                             Professional developer    Male
# 51383       51384                             Professional developer    Male
# 51384       51385                             Professional developer    Male
# 51385       51386                Used to be a professional developer  Female
# 51386       51387                             Professional developer    Male
# 51387       51388                             Professional developer    Male
# 51388       51389                                            Student    Male
# 51389       51390                             Professional developer     NaN
# 51390       51391                             Professional developer    Male
# 51391       51392  Professional non-developer who sometimes write...    Male
#
#                                                     race         country  \
# 0                           White or of European descent   United States
# 1                           White or of European descent  United Kingdom
# 2                           White or of European descent  United Kingdom
# 3                           White or of European descent   United States
# 4                                                    NaN     Switzerland
# 5                           White or of European descent     New Zealand
# 6                           White or of European descent   United States
# 7                           White or of European descent          Poland
# 8                              Hispanic or Latino/Latina        Colombia
# 9                           White or of European descent          France
# 10                          White or of European descent   United States
# 11                                                   NaN          Canada
# 12                          White or of European descent  United Kingdom
# 13                             Hispanic or Latino/Latina         Germany
# 14                          White or of European descent  United Kingdom
# 15                          White or of European descent   United States
# 16                          White or of European descent  United Kingdom
# 17     Native American, Pacific Islander, or Indigeno...   United States
# 18                                                   NaN   United States
# 19                                   I prefer not to say          Greece
# 20                                                   NaN          Brazil
# 21                          White or of European descent  United Kingdom
# 22                          White or of European descent          Israel
# 23                          White or of European descent           Italy
# 24                                                   NaN         Belgium
# 25                          White or of European descent   United States
# 26                                                   NaN           India
# 27                                                   NaN   United States
# 28                          White or of European descent          Israel
# 29                                                   NaN   United States
# ...                                                  ...             ...
# 51362                       White or of European descent   United States
# 51363                       White or of European descent         Estonia
# 51364                       White or of European descent         Germany
# 51365                       White or of European descent  Czech Republic
# 51366                                                NaN          Sweden
# 51367  Hispanic or Latino/Latina; White or of Europea...           Spain
# 51368                       White or of European descent          Taiwan
# 51369                       White or of European descent          Poland
# 51370                       White or of European descent  United Kingdom
# 51371                       White or of European descent     Netherlands
# 51372                                                NaN  United Kingdom
# 51373                                                NaN   United States
# 51374                                                NaN          Sweden
# 51375                       White or of European descent  United Kingdom
# 51376                       White or of European descent         Germany
# 51377                                                NaN  United Kingdom
# 51378                                                NaN          Cyprus
# 51379                                                NaN         Belgium
# 51380                       White or of European descent   United States
# 51381                       White or of European descent   United States
# 51382                       White or of European descent          France
# 51383                       White or of European descent          Sweden
# 51384                       White or of European descent   United States
# 51385                       White or of European descent  United Kingdom
# 51386                       White or of European descent         Romania
# 51387           East Asian; White or of European descent   United States
# 51388  Black or of African descent; Hispanic or Latin...       Venezuela
# 51389                                                NaN          Canada
# 51390                       White or of European descent   United States
# 51391                       White or of European descent         Ireland
#
#                           currency           university  \
# 0                              NaN                   No
# 1      British pounds sterling (£)       Yes, full-time
# 2      British pounds sterling (£)                   No
# 3                              NaN                   No
# 4                              NaN                   No
# 5                              NaN       Yes, full-time
# 6                              NaN                   No
# 7                              NaN                   No
# 8                              NaN       Yes, part-time
# 9                              NaN       Yes, full-time
# 10                             NaN                   No
# 11           Canadian dollars (C$)                   No
# 12                             NaN                   No
# 13                             NaN                   No
# 14     British pounds sterling (£)                   No
# 15                             NaN       Yes, part-time
# 16                             NaN                   No
# 17                U.S. dollars ($)       Yes, part-time
# 18                U.S. dollars ($)                   No
# 19                       Euros (€)                   No
# 20            Brazilian reais (R$)                   No
# 21                             NaN                   No
# 22                U.S. dollars ($)                   No
# 23                             NaN                   No
# 24                             NaN                   No
# 25                U.S. dollars ($)                   No
# 26               Indian rupees (?)                   No
# 27                             NaN                   No
# 28                             NaN                   No
# 29                             NaN                   No
# ...                            ...                  ...
# 51362                          NaN                   No
# 51363                          NaN  I prefer not to say
# 51364                          NaN                   No
# 51365                          NaN                   No
# 51366                          NaN                   No
# 51367                          NaN       Yes, full-time
# 51368                          NaN                   No
# 51369            Polish zloty (zl)       Yes, full-time
# 51370                          NaN                   No
# 51371                    Euros (€)                   No
# 51372  British pounds sterling (£)       Yes, full-time
# 51373                          NaN                   No
# 51374         Swedish kroner (SEK)                   No
# 51375  British pounds sterling (£)                   No
# 51376                    Euros (€)       Yes, full-time
# 51377  British pounds sterling (£)                   No
# 51378                    Euros (€)                   No
# 51379                    Euros (€)                   No
# 51380                          NaN                   No
# 51381                          NaN                   No
# 51382                    Euros (€)                   No
# 51383                          NaN                   No
# 51384                          NaN                   No
# 51385                          NaN                   No
# 51386                          NaN                   No
# 51387             U.S. dollars ($)                   No
# 51388                          NaN       Yes, full-time
# 51389                          NaN                   No
# 51390             U.S. dollars ($)                   No
# 51391                          NaN                   No
#
#                                           majorundergrad         salary  \
# 0                                                    NaN            NaN
# 1               Computer science or software engineering            NaN
# 2               Computer science or software engineering  113750.000000
# 3          A non-computer-focused engineering discipline            NaN
# 4               Computer science or software engineering            NaN
# 5                                                    NaN            NaN
# 6          A non-computer-focused engineering discipline            NaN
# 7               Computer science or software engineering            NaN
# 8               Computer science or software engineering            NaN
# 9               Computer science or software engineering            NaN
# 10                                      A social science            NaN
# 11              Computer science or software engineering            NaN
# 12                             Mathematics or statistics            NaN
# 13              Computer science or software engineering            NaN
# 14     Computer engineering or electrical/electronics...  100000.000000
# 15                                                   NaN            NaN
# 16                                                   NaN            NaN
# 17              Computer science or software engineering  130000.000000
# 18              Computer science or software engineering   82500.000000
# 19                                     A natural science            NaN
# 20              Computer science or software engineering            NaN
# 21                                     A natural science            NaN
# 22     Computer engineering or electrical/electronics...  100764.000000
# 23                                                   NaN            NaN
# 24              Computer science or software engineering            NaN
# 25              Computer science or software engineering  175000.000000
# 26              Computer science or software engineering            NaN
# 27                                 A business discipline            NaN
# 28     Computer engineering or electrical/electronics...            NaN
# 29                                 A business discipline            NaN
# ...                                                  ...            ...
# 51362                     Management information systems            NaN
# 51363  Information technology, networking, or system ...            NaN
# 51364                                                NaN            NaN
# 51365                                  A natural science            NaN
# 51366           Computer science or software engineering            NaN
# 51367  Computer engineering or electrical/electronics...            NaN
# 51368                                   A social science            NaN
# 51369           Computer science or software engineering            NaN
# 51370                           I never declared a major            NaN
# 51371           Computer science or software engineering   74193.548387
# 51372                                                NaN            NaN
# 51373           Computer science or software engineering            NaN
# 51374           Computer science or software engineering            NaN
# 51375            Computer programming or Web development            NaN
# 51376                                                NaN            NaN
# 51377           Computer science or software engineering            NaN
# 51378                                                NaN  107526.881720
# 51379      A non-computer-focused engineering discipline            NaN
# 51380            Computer programming or Web development            NaN
# 51381                                         Psychology            NaN
# 51382           Computer science or software engineering   32258.064516
# 51383                                                NaN            NaN
# 51384            Computer programming or Web development            NaN
# 51385                              A business discipline            NaN
# 51386                                     Something else            NaN
# 51387                                   A social science   58000.000000
# 51388            Computer programming or Web development            NaN
# 51389  Information technology, networking, or system ...            NaN
# 51390           Computer science or software engineering   40000.000000
# 51391           Computer science or software engineering            NaN
#
#        expectedsalary
# 0                 NaN
# 1        37500.000000
# 2                 NaN
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
# 10                NaN
# 11                NaN
# 12                NaN
# 13                NaN
# 14                NaN
# 15                NaN
# 16                NaN
# 17                NaN
# 18                NaN
# 19                NaN
# 20                NaN
# 21                NaN
# 22                NaN
# 23                NaN
# 24                NaN
# 25                NaN
# 26                NaN
# 27                NaN
# 28                NaN
# 29                NaN
# ...               ...
# 51362             NaN
# 51363             NaN
# 51364             NaN
# 51365             NaN
# 51366             NaN
# 51367             NaN
# 51368             NaN
# 51369    14814.814815
# 51370             NaN
# 51371             NaN
# 51372             NaN
# 51373             NaN
# 51374             NaN
# 51375             NaN
# 51376    43010.752688
# 51377             NaN
# 51378             NaN
# 51379    26881.720430
# 51380             NaN
# 51381             NaN
# 51382             NaN
# 51383             NaN
# 51384             NaN
# 51385             NaN
# 51386             NaN
# 51387             NaN
# 51388             NaN
# 51389             NaN
# 51390             NaN
# 51391             NaN
#
# [51392 rows x 10 columns]

# %%
df_dev_skill = df[['respondent', 'haveworkedlanguage', 'haveworkeddatabase', 'haveworkedframework', 'haveworkedplatform', 
                  'wantworklanguage', 'wantworkdatabase', 'wantworkframework', 'wantworkplatform', 'ide', 'versioncontrol',
                    'yearscodedjob']]

# %%
df_dev_skill.head()
# Out:
#    respondent             haveworkedlanguage  \
# 0           1                          Swift
# 1           2  JavaScript; Python; Ruby; SQL
# 2           3              Java; PHP; Python
# 3           4         Matlab; Python; R; SQL
# 4           5                            NaN
#
#                           haveworkeddatabase haveworkedframework  \
# 0                                        NaN                 NaN
# 1                              MySQL; SQLite           .NET Core
# 2                                      MySQL                 NaN
# 3  MongoDB; Redis; SQL Server; MySQL; SQLite               React
# 4                                        NaN                 NaN
#
#                                   haveworkedplatform         wantworklanguage  \
# 0                                                iOS                    Swift
# 1                          Amazon Web Services (AWS)  Java; Python; Ruby; SQL
# 2                                                NaN          C; Python; Rust
# 3  Windows Desktop; Linux Desktop; Mac OS; Amazon...   Matlab; Python; R; SQL
# 4                                                NaN                      NaN
#
#                             wantworkdatabase       wantworkframework  \
# 0                                        NaN                     NaN
# 1                              MySQL; SQLite               .NET Core
# 2                                        NaN                     NaN
# 3  MongoDB; Redis; SQL Server; MySQL; SQLite  Hadoop; Node.js; React
# 4                                        NaN                     NaN
#
#                                     wantworkplatform  \
# 0                                                iOS
# 1  Linux Desktop; Raspberry Pi; Amazon Web Servic...
# 2                                                NaN
# 3  Windows Desktop; Linux Desktop; Mac OS; Amazon...
# 4                                                NaN
#
#                                                  ide versioncontrol  \
# 0                                        Atom; Xcode            NaN
# 1  Atom; Notepad++; Vim; PyCharm; RubyMine; Visua...            Git
# 2                        Sublime Text; Vim; IntelliJ      Mercurial
# 3  Notepad++; Sublime Text; TextMate; Vim; IPytho...            Git
# 4                                                NaN            NaN
#
#       yearscodedjob
# 0               NaN
# 1               NaN
# 2  20 or more years
# 3     9 to 10 years
# 4    10 to 11 years

# %%
df_dev_category = df[['respondent', 'developertype', 'webdevelopertype', 'mobiledevelopertype', 'nondevelopertype']]

# %%
df_dev_category
# Out:
#        respondent                                      developertype  \
# 0               1                                                NaN
# 1               2                                                NaN
# 2               3                                              Other
# 3               4                                                NaN
# 4               5  Mobile developer; Graphics programming; Deskto...
# 5               6                                                NaN
# 6               7                                                NaN
# 7               8                                      Web developer
# 8               9                    Web developer; Mobile developer
# 9              10   Mobile developer; Desktop applications developer
# 10             11                                                NaN
# 11             12                                      Web developer
# 12             13                                                NaN
# 13             14                                      Web developer
# 14             15            Embedded applications/devices developer
# 15             16                     Desktop applications developer
# 16             17                                      Web developer
# 17             18  Web developer; Embedded applications/devices d...
# 18             19                                      Web developer
# 19             20                              Data scientist; Other
# 20             21                                      Web developer
# 21             22  Web developer; Mobile developer; Desktop appli...
# 22             23                                              Other
# 23             24                                      Web developer
# 24             25                               Web developer; Other
# 25             26                                      Web developer
# 26             27                    Web developer; Mobile developer
# 27             28      Web developer; Desktop applications developer
# 28             29                                                NaN
# 29             30                                                NaN
# ...           ...                                                ...
# 51362       51363                                      Web developer
# 51363       51364              Web developer; Database administrator
# 51364       51365  Web developer; Mobile developer; Desktop appli...
# 51365       51366                                              Other
# 51366       51367  Web developer; Desktop applications developer;...
# 51367       51368                                                NaN
# 51368       51369                                   Mobile developer
# 51369       51370                                                NaN
# 51370       51371                                      Web developer
# 51371       51372  Web developer; Machine learning specialist; De...
# 51372       51373                                      Web developer
# 51373       51374                               Graphics programming
# 51374       51375                                      Web developer
# 51375       51376                    Web developer; Mobile developer
# 51376       51377                                                NaN
# 51377       51378                                      Web developer
# 51378       51379                Mobile developer; DevOps specialist
# 51379       51380                                                NaN
# 51380       51381                                              Other
# 51381       51382                                                NaN
# 51382       51383                                      Web developer
# 51383       51384  Web developer; Mobile developer; Desktop appli...
# 51384       51385                                      Web developer
# 51385       51386                                                NaN
# 51386       51387  Web developer; Mobile developer; Developer wit...
# 51387       51388  Web developer; Developer with a statistics or ...
# 51388       51389                                                NaN
# 51389       51390               Web developer; Systems administrator
# 51390       51391                    Web developer; Mobile developer
# 51391       51392                                                NaN
#
#                webdevelopertype mobiledevelopertype  \
# 0                           NaN                 NaN
# 1                           NaN                 NaN
# 2                           NaN                 NaN
# 3                           NaN                 NaN
# 4                           NaN                 NaN
# 5                           NaN                 NaN
# 6                           NaN                 NaN
# 7      Full stack Web developer                 NaN
# 8                           NaN                 NaN
# 9                           NaN                 NaN
# 10                          NaN                 NaN
# 11       Back-end Web developer                 NaN
# 12                          NaN                 NaN
# 13     Full stack Web developer                 NaN
# 14                          NaN                 NaN
# 15                          NaN                 NaN
# 16     Full stack Web developer                 NaN
# 17                          NaN                 NaN
# 18     Full stack Web developer                 NaN
# 19                          NaN                 NaN
# 20     Full stack Web developer                 NaN
# 21                          NaN                 NaN
# 22                          NaN                 NaN
# 23     Full stack Web developer                 NaN
# 24                          NaN                 NaN
# 25       Back-end Web developer                 NaN
# 26                          NaN                 NaN
# 27                          NaN                 NaN
# 28                          NaN                 NaN
# 29                          NaN                 NaN
# ...                         ...                 ...
# 51362  Full stack Web developer                 NaN
# 51363                       NaN                 NaN
# 51364                       NaN                 NaN
# 51365                       NaN                 NaN
# 51366                       NaN                 NaN
# 51367                       NaN                 NaN
# 51368                       NaN                 iOS
# 51369                       NaN                 NaN
# 51370  Full stack Web developer                 NaN
# 51371                       NaN                 NaN
# 51372  Full stack Web developer                 NaN
# 51373                       NaN                 NaN
# 51374    Back-end Web developer                 NaN
# 51375                       NaN                 NaN
# 51376                       NaN                 NaN
# 51377    Back-end Web developer                 NaN
# 51378                       NaN                 NaN
# 51379                       NaN                 NaN
# 51380                       NaN                 NaN
# 51381                       NaN                 NaN
# 51382   Front-end Web developer                 NaN
# 51383                       NaN                 NaN
# 51384   Front-end Web developer                 NaN
# 51385                       NaN                 NaN
# 51386                       NaN                 NaN
# 51387                       NaN                 NaN
# 51388                       NaN                 NaN
# 51389                       NaN                 NaN
# 51390                       NaN                 NaN
# 51391                       NaN                 NaN
#
#                          nondevelopertype
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                          Data scientist
# 4                                     NaN
# 5                                     NaN
# 6                          Data scientist
# 7                                     NaN
# 8                                     NaN
# 9                                     NaN
# 10                                  Other
# 11                                    NaN
# 12                                    NaN
# 13                                    NaN
# 14                                    NaN
# 15                                    NaN
# 16                                    NaN
# 17                                    NaN
# 18                                    NaN
# 19                                    NaN
# 20                                    NaN
# 21                                    NaN
# 22                                    NaN
# 23                                    NaN
# 24                                    NaN
# 25                                    NaN
# 26                                    NaN
# 27                                    NaN
# 28     C-suite executive; Product manager
# 29                                  Other
# ...                                   ...
# 51362                                 NaN
# 51363                                 NaN
# 51364                                 NaN
# 51365                                 NaN
# 51366                                 NaN
# 51367                                 NaN
# 51368                                 NaN
# 51369                                 NaN
# 51370                                 NaN
# 51371                                 NaN
# 51372                                 NaN
# 51373                                 NaN
# 51374                                 NaN
# 51375                                 NaN
# 51376                                 NaN
# 51377                                 NaN
# 51378                                 NaN
# 51379                                 NaN
# 51380                                 NaN
# 51381                      Data scientist
# 51382                                 NaN
# 51383                                 NaN
# 51384                                 NaN
# 51385                                 NaN
# 51386                                 NaN
# 51387                                 NaN
# 51388                                 NaN
# 51389                                 NaN
# 51390                                 NaN
# 51391                               Other
#
# [51392 rows x 5 columns]

# %%
df_dev_life = df[['respondent', 'jobsatisfaction', 'careersatisfaction', 'importantbenefits', 'auditoryenvironment']]

# %%
df_dev_life.head()
# Out:
#    respondent  jobsatisfaction  careersatisfaction  \
# 0           1              NaN                 NaN
# 1           2              NaN                 NaN
# 2           3              9.0                 8.0
# 3           4              3.0                 6.0
# 4           5              8.0                 6.0
#
#                                    importantbenefits  \
# 0   Stock options; Vacation/days off; Remote options
# 1                                                NaN
# 2                                                NaN
# 3  Stock options; Annual bonus; Health benefits; ...
# 4                                                NaN
#
#                                  auditoryenvironment
# 0                                 Turn on some music
# 1  Put on some ambient sounds (e.g. whale songs, ...
# 2                                 Turn on some music
# 3                                 Turn on some music
# 4                                                NaN

# %%
import psycopg2
from sqlalchemy import create_engine

# %%
conn = psycopg2.connect("dbname='stack_overflow_survey' user='DarkWizard' host='localhost'")
cur = conn.cursor()
engine = create_engine(r'postgresql://DarkWizard@localhost/stack_overflow_survey')

# %%
print("Building the dev_profiles table")
df_dev_profile.to_sql('dev_profiles', engine)
print("Have built the dev_profiles table")
# Out:
# Building the dev_profiles table
# Have built the dev_profiles table

# %%
print("Building the dev_skill table")
df_dev_skill.to_sql('dev_skill', engine, index=False)
print("Have built the dev_skill table")
# Out:
# Building the dev_skill table
# Have built the dev_skill table

# %%
print("Building the dev_category table")
df_dev_category.to_sql('dev_category', engine, index=False)
print("Have built the dev_category table")
# Out:
# Building the dev_category table
# Have built the dev_category table

# %%
print("Building the dev_life table")
df_dev_life.to_sql('dev_life', engine, index=False)
print("Have built the dev_life table")
# Out:
# Building the dev_life table
# --
# ValueErrorTraceback (most recent call last)
# <ipython-input-106-46183526af71> in <module>()
#       1 print("Building the dev_life table")
# ----> 2 df_dev_life.to_sql('dev_life', engine, index=False)
#       3 print("Have built the dev_life table")
#
# /usr/local/lib/python3.6/site-packages/pandas/core/generic.py in to_sql(self, name, con, flavor, schema, if_exists, index, index_label, chunksize, dtype)
#    1532         sql.to_sql(self, name, con, flavor=flavor, schema=schema,
#    1533                    if_exists=if_exists, index=index, index_label=index_label,
# -> 1534                    chunksize=chunksize, dtype=dtype)
#    1535
#    1536     def to_pickle(self, path, compression='infer',
#
# /usr/local/lib/python3.6/site-packages/pandas/io/sql.py in to_sql(frame, name, con, flavor, schema, if_exists, index, index_label, chunksize, dtype)
#     471     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
#     472                       index_label=index_label, schema=schema,
# --> 473                       chunksize=chunksize, dtype=dtype)
#     474
#     475
#
# /usr/local/lib/python3.6/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype)
#    1153                          if_exists=if_exists, index_label=index_label,
#    1154                          schema=schema, dtype=dtype)
# -> 1155         table.create()
#    1156         table.insert(chunksize)
#    1157         if (not name.isdigit() and not name.islower()):
#
# /usr/local/lib/python3.6/site-packages/pandas/io/sql.py in create(self)
#     590         if self.exists():
#     591             if self.if_exists == 'fail':
# --> 592                 raise ValueError("Table '%s' already exists." % self.name)
#     593             elif self.if_exists == 'replace':
#     594                 self.pd_sql.drop_table(self.name, self.schema)
#
# ValueError: Table 'dev_life' already exists.

# %% [markdown]
# 51392 people took the survey

# %%
gender_counts = df['gender'].value_counts()

# %%
gender_counts[:10].plot(kind='bar')

# %%
race_counts = df['race'].value_counts()
race_counts[:10].plot(kind='bar')

# %%
country_counts = df['country'].value_counts()
country_counts[:10].plot(kind='bar')

# %%
profession_counts = df['professional'].value_counts()
profession_counts[:10].plot(kind='bar')

# %%
majorundergrad_counts = df['majorundergrad'].value_counts()
majorundergrad_counts[:10].plot(kind='bar')

# %%
wantworklanguage_counts = df['wantworklanguage'].value_counts()
wantworklanguage_counts[:10].plot(kind='bar')

# %%
wantworkplatform_counts = df['wantworkplatform'].value_counts()
wantworkplatform_counts[:20].plot(kind='bar')

# %%
wantworkdatabase_counts = df['wantworkdatabase'].value_counts()
wantworkdatabase_counts[:20].plot(kind='bar')

# %%
yearscodedjob_counts = df['yearscodedjob'].value_counts()
yearscodedjob_counts[:20].plot(kind='bar')

# %%
importantbenefits_counts = df['importantbenefits'].value_counts()
importantbenefits_counts[:10].plot(kind='bar')

# %%
query = """SELECT country, salary, developertype
            FROM(SELECT dev_profiles.respondent, country, salary, developertype FROM dev_profiles INNER JOIN dev_category ON dev_category.respondent=dev_profiles.respondent)
            AS joinedtable
            WHERE LOWER(developertype) LIKE '%database%' AND salary>1 AND country LIKE 'United States' ORDER BY salary DESC;
            """

a = cur.execute(query)
db_salary = cur.fetchall()

# %%
lst = []
for i in b:
    lst.append(i[1])

plt.plot(lst)
plt.show()

# %%
lst_test = [1,2,3,4]
with open("ls_test.json", "a+") as f:
    for i in lst_test:
        f.write(str(i))
        f.write('\n')
        f.close
